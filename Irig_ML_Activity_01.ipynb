# %% [markdown]
# <a href="https://colab.research.google.com/github/coachengilbert-svg/ML_Proj-compilation/blob/main/Irig_ML_Activity_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
iris = load_iris()

# %%
df = pd.DataFrame(
iris.data,
columns=iris.feature_names
)
df['species'] = iris.target_names[iris.target]
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
print("Number of observation:", df.shape[0])
print("Number of features:", df.shape[1]-1)
# Out:
# Number of observation: 150
# Number of features: 4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
plt.figure(figsize=(8,6))
plt.scatter(
    df["sepal length (cm)"],
    df["sepal width (cm)"]
)
plt.xlabel("Sepal length (cm)")
plt.ylabel("Sepal width (cm)")
plt.title("Sepal Length vs sepal Width")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(8,6))

for species in df["species"].unique():
  subset = df[df["species"]==species]

  plt.scatter(
      subset["sepal length (cm)"],
      subset["sepal width (cm)"],
      label = species
  )

  plt.xlabel("Sepal length (cm)")
  plt.ylabel("Sepal width (cm)")
  plt.title("Iris species distribution")
  plt.legend()

  plt.show()

# %%
plt.figure(figsize=(8,6))

for species in df["species"].unique():
  subset = df[df["species"]==species]

  plt.scatter(
      subset["petal length (cm)"],
      subset["petal width (cm)"],
      label = species
  )

  plt.xlabel("petal length (cm)")
  plt.ylabel("petal width (cm)")
  plt.title("Iris species based on petal measurements")
  plt.legend

  plt.show()

# %%
x = iris.data
y = iris.target

# %%
print("X Shape:", x.shape)
print("Y Shape:", y.shape)
# Out:
# X Shape: (150, 4)
# Y Shape: (150,)

# %%
X_train,X_test, y_train, y_train = train_test_split(
x,
y,
test_size=0.20,
random_state=42,
stratify=y
)

# %%
model=KNeighborsClassifier(n_neighbors=3)

# %%
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1392/180087699.py in <cell line: 0>()
# ----> 1 model.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %%
y_pred = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1392/2891402613.py in <cell line: 0>()
# ----> 1 y_pred = model.predict(X_test)
#
# NameError: name 'X_test' is not defined

# %%
print("Actual: ")
print(y_test)

print("\nPredicted:")
print(y_pred)
# Out:
# Actual:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1392/4009566810.py in <cell line: 0>()
#       1 print("Actual: ")
# ----> 2 print(y_test)
#       3
#       4 print("\nPredicted:")
#       5 print(y_pred)
#
# NameError: name 'y_test' is not defined

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1392/3331364415.py in <cell line: 0>()
# ----> 1 accuracy = accuracy_score(y_test, y_pred)
#       2 print("Accuracy:", accuracy)
#
# NameError: name 'y_test' is not defined

# %%
new_flower=[[5.1, 3.5, 1.4, 0.2]]

# %%
prediction = model.predict(new_flower)
print(
    "Predict Species: ",
    iris.target_names[prediction[0]]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1392/3235802342.py in <cell line: 0>()
# ----> 1 prediction = model.predict(new_flower)
#       2 print(
#       3     "Predict Species: ",
#       4     iris.target_names[prediction[0]]
#       5 )
#
# NameError: name 'model' is not defined
